# %% [markdown]
# ### when dummies are used, for example there are 2 values in sex series, m and f, then original sex series will be replaced by sex_m and sex_f and it will contain binary values 0 and 1 only. for the values present 1 will be there

# %%
import pandas as pd

# %%
data=pd.read_csv("/home/ila/PycharmProjects/pythonworks/artificialintelligence/pandas/files/kaggletrain.txt")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
x=data.iloc[:,0:2]
y=data.iloc[:,-1]
data['gender_binary']=data.Sex.map({'female':0,'male':1})
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  gender_binary
# 0      0         A/5 21171   7.2500   NaN        S              1
# 1      0          PC 17599  71.2833   C85        C              0
# 2      0  STON/O2. 3101282   7.9250   NaN        S              0
# ...

# %%
pd.get_dummies(data.Sex).head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
x.head()
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: gender_binary, dtype: int64

# %%
pd.get_dummies(data.Sex).iloc[:,:].head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
pd.get_dummies(data.Sex,prefix='Sex_').iloc[:,1:].head()
# Out:
#    Sex__male
# 0          1
# 1          0
# 2          0
# 3          0
# 4          1

# %%
data.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  gender_binary
# 0      0         A/5 21171   7.2500   NaN        S              1
# 1      0          PC 17599  71.2833   C85        C              0
# 2      0  STON/O2. 3101282   7.9250   NaN        S              0
# ...

# %%
pd.get_dummies(data,columns=['Sex','Pclass']).head()
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# 5              6         0                                   Moran, Mr. James
# 6              7         0                            McCarthy, Mr. Timothy J
# 7              8         0                     Palsson, Master. Gosta Leonard
# 8              9         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             10         1                Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
pd.get_dummies(data,columns=['Sex','Pclass'],drop_first=True).head()#Sex_female and Pclass_1 will be dropped. makes sense for binary columns
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  38.0      1      0          PC 17599  71.2833   C85        C
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  35.0      1      0            113803  53.1000  C123        S
# 4  35.0      0      0            373450   8.0500   NaN        S
#
#    gender_binary  Sex_male  Pclass_2  Pclass_3
# 0              1         1         0         1
# ...

# %%
# Out:
# PassengerId        int64
# Survived           int64
# Pclass             int64
# Name              object
# Sex               object
# Age              float64
# SibSp              int64
# Parch              int64
# Ticket            object
# Fare             float64
# Cabin             object
# Embarked          object
# gender_binary      int64
# dtype: object
