# %%
import pandas as pd

# %%
my_sheet = 'Sheet1'
file_name = '/home/ila/Desktop/cache/2.0.18/results/10_9_19_all_fields_train_spacy_format_with_nearest_aslinesaugmented_all_edited_2.0.18_50.xlsx' # name of your excel file
df = pd.read_excel(file_name)
df.head() # shows headers with top 5 rows
# Out:
#              patient_tag_name  patient_tag_name.1 patient_name_in_document  \
# 0                         NaN                 NaN                      NaN
# 1  Aetna Claim cb-16-508w.pdf                 NaN        Karin T. Briganti
# 2    SKM_C454e19032114320.pdf                 NaN                      NaN
# 3    SKM_C454e19032114320.pdf                 NaN                      NaN
# 4    SKM_C454e19032114320.pdf                 NaN                      NaN
#
#   patient_name_in_document.1      patient_dob_tag    patient_dob_tag.1  \
# 0                        NaN                  NaN                  NaN
# 1          karin t. briganti  Patient's birthdate  patient's birthdate
# 2                        NaN   Patient Birth Date            birthdate
# 3                        NaN        Date of Birth                  NaN
# 4                        NaN        Date of Birth                  NaN
#
#   patient_dob patient_dob.1 patient_ssn_tag patient_ssn_tag.1  ...  \
# ...
