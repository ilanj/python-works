# %%
# %matplotlib inline
import pandas as pd
data = pd.read_csv("../data/heart-disease.csv")
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#create histograme with age
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
data["age"].plot.hist(bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.hist(figsize=(10,30),subplots=True);

# %%
data.plot(kind='scatter', x='age', y='chol', c='target')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
data.plot(kind='scatter', x='age', y='chol', c='thal')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
data.plot(kind='scatter', x='age', y='chol')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
#using matplotlib
import matplotlib.pyplot as plt
fix, ax = plt.subplots(figsize=(10,6))
data.plot(kind='scatter', 
         x='age',
         y = 'chol',
         ax=ax)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
#new scatter plot
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=data["age"],
                    y=data['chol'],
                     c=data['target']
                    )

ax.set(title="heart disease and cholestrol levels",
      xlabel="Age",
      ylabel="Cholestrol")
ax.legend(*scatter.legend_elements(), title="Target")
