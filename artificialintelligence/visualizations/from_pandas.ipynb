# %%
# %matplotlib inline
import pandas as pd
data = pd.read_csv("../data/car-sales.csv")
data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
#pandas built onmatplotlib, plotting with pandas only
pplot = pd.Series([1,2,3,4], [33,55,22,78])
pplot.plot()
# Out:
# <AxesSubplot:>

# %%
#price is string and contains $. we can clean 
data["Price"] = data["Price"].str.replace(r"\D", "")
data["Price"] = data["Price"].str[:-2]

# %%
data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500

# %%
#Price is missing as datat type is str
data.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
data["Price"] = data["Price"].astype(int)

# %%
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
pplot = pd.Series(data["Odometer (KM)"], data["Price"])
pplot.plot();

# %%
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
#insert new date series
data["sales_date"] = pd.date_range("1/1/2021", periods=data.count()["Price"])

# %%
data["sales_date"]
# Out:
# 0   2021-01-01
# 1   2021-01-02
# 2   2021-01-03
# 3   2021-01-04
# 4   2021-01-05
# 5   2021-01-06
# 6   2021-01-07
# 7   2021-01-08
# 8   2021-01-09
# 9   2021-01-10
# Name: sales_date, dtype: datetime64[ns]

# %%
data.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
data.plot(x="Odometer (KM)", y="Price", kind="bar")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)'>

# %%
data.plot(x="Odometer (KM)", y="Price", kind="line")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)'>

# %%
#histogram
data["Price"].plot.hist();

# %%
#histogram
data["Price"].plot.hist(bins=5); #bins = no of bars

# %%
text = "haai  456 wecome"
text.replace(r"haai", "f")
text
# Out:
# 'haai  456 wecome'

# %%
price = pd.read_csv("../pandas/files/sq_price.csv")
price.head()
# Out:
#    sq.feet   price
# 0      100  150000
# 1      200  302222
# 2      300  450000
# 3      400  609546
# 4      500  750000

# %%
price.plot(x="sq.feet", y="price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='sq.feet', ylabel='price'>

# %%
price.dtypes
# Out:
# sq.feet    int64
# price      int64
# dtype: object
