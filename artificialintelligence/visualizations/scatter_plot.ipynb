# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#create some data
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
#plot the data
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %%
#scatter plot
fig, ax = plt.subplots()
ax.scatter(x, x**12)

# %%
fig, ax = plt.subplots()
x1 = [1,3,5,6,7]
y1 = [12, 13, 65, 77, 89]
ax.scatter(x1, y1)

# %%
#sin wave
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
#example-2
y2 = np.random.randn(100)
y2[:]
# Out:
# array([ 1.41725515, -0.18616997, -0.85708891, -0.09136901,  0.80392692,
#         2.47861746, -0.12197539,  0.32755183,  2.31414014, -0.43735569,
#         1.3262538 ,  0.25469643, -0.33329703,  0.35861569,  0.00559891,
#         0.10710195, -1.15707184,  0.36698403,  1.14253426, -0.12200054,
#         0.18673809,  0.59019034, -0.12203374, -0.86357644,  0.63913792,
#         1.0161532 ,  2.10628295,  0.39859784,  0.02078435,  0.66325425,
#        -0.39407183, -1.99039486, -1.14033585, -0.40684759,  0.67707232,
#        -0.15581913,  0.78335952, -1.56262897,  0.17358467,  0.35915377,
#         0.58736122, -0.81175135,  0.83527577, -0.30434614,  1.30206696,
#         0.32613969,  0.30650474,  1.09149528, -0.28084387, -1.63719001,
#         0.47789567,  0.56812902, -0.00923495, -0.05798348, -0.59282018,
#         0.45041998,  0.6861481 ,  0.38064052, -0.4518096 ,  1.00560459,
#         0.21887209, -1.02895625,  0.57954535, -0.28908538,  0.19003272,
# ...

# %% [markdown]
# #

# %%
fig, ax = plt.subplots()
ax.plot(x, y2)
